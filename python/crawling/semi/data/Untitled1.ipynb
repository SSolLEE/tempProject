# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\tempProject\\python\\crawling\\semi\\data'

# %%
import pandas as pd
data = pd.read_csv("../raw/서울교통공사_역별시간대별혼잡도_20211231.csv", encoding = "euc-kr")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 42 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   조사일자    1704 non-null   object
#  1   호선      1704 non-null   int64
#  2   역번호     1704 non-null   int64
#  3   역명      1704 non-null   object
#  4   구분      1704 non-null   object
#  5   05시30분  1647 non-null   float64
#  6   06시00분  1689 non-null   float64
#  7   06시30분  1689 non-null   float64
#  8   07시00분  1689 non-null   float64
#  9   07시30분  1689 non-null   float64
#  10  08시00분  1689 non-null   float64
#  11  08시30분  1689 non-null   float64
#  12  09시00분  1689 non-null   float64
#  13  09시30분  1689 non-null   float64
#  14  10시00분  1689 non-null   float64
#  15  10시30분  1689 non-null   float64
#  16  11시00분  1689 non-null   float64
#  17  11시30분  1689 non-null   float64
#  18  12시00분  1689 non-null   float64
#  19  12시30분  1689 non-null   float64
#  20  13시00분  1689 non-null   float64
# ...

# %%
new_column_names = {'호선명': '호선', '지하철역': '역명', '사용월': '월'}

# 컬럼명 변경
data.rename(columns=new_column_names, inplace=True)

# %%
data
# Out:
#        호선   역명   월        비율
# 0     1호선  동대문   1  0.954919
# 1     1호선  동대문   2  0.882286
# 2     1호선  동대문   3  1.052501
# 3     1호선  동대문   4  1.032322
# 4     1호선  동대문   5  1.080913
# ...   ...  ...  ..       ...
# 3426  8호선   천호   8  0.971984
# 3427  8호선   천호   9  0.949856
# 3428  8호선   천호  10  1.011985
# 3429  8호선   천호  11  1.017343
# 3430  8호선   천호  12  1.049061
#
# [3431 rows x 4 columns]
