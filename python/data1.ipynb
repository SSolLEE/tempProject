# %%
import requests
import pandas as pd

url = "http://openapi.seoul.go.kr:8088/4e504750706c736f39374252465a73/json/tbLnOpendataRtmsV/1/5/"
req = requests.get(url)
print(req)
json_df = req.json()
# json_df
# json_df.keys()
json_df['tbLnOpendataRtmsV'].keys()
# Out:
# <Response [200]>
# dict_keys(['list_total_count', 'RESULT', 'row'])

# %%
houses = json_df['tbLnOpendataRtmsV']['row']
data_1 = pd.DataFrame(houses)
print(data_1)
# Out:
#   ACC_YEAR SGG_CD SGG_NM BJDONG_CD BJDONG_NM LAND_GBN LAND_GBN_NM BONBEON  \
# 0     2023  11710    송파구     10800       문정동        1          대지    0652
# 1     2023  11560   영등포구     10900    영등포동8가        1          대지    0051
# 2     2023  11380    은평구     10500       구산동        1          대지    0345
# 3     2023  11620    관악구     10100       봉천동        1          대지    1708
# 4     2023  11500    강서구     10300       화곡동        1          대지    1071
#
#   BUBEON    BLDG_NM  ... OBJ_AMT BLDG_AREA  TOT_AREA  FLOOR  RIGHT_GBN  \
# 0   0004  힐스테이트에코문정  ...   20500     20.79     32.68    4.0
# 1   0001        메이준  ...    8000     17.44     25.56    6.0
# 2   0020      솔빛엘르빌  ...   22000     49.30     27.73    2.0
# 3   0000         두산  ...   80000     59.92      0.00   10.0
# 4   0007       와이앤비  ...   22500     25.38     15.19    3.0
#
#   CNTL_YMD BUILD_YEAR HOUSE_TYPE REQ_GBN RDEALER_LAWDNM
# 0                2018       오피스텔    중개거래         서울 송파구
# ...

# %%
data_1.to_csv("서울시부동산실거래가_1.csv", index=False)

# %%
import requests
import pandas as pd

url = "http://openAPI.yongsan.go.kr:8088/4b506461526c736f3238486c426578/json/YsModelRestaurantApply/1/198/"
req = requests.get(url)
print(req)
apply_yongsan = req.json()
apply_yongsan 
apply_yongsan.keys()
apply_yongsan['YsModelRestaurantApply'].keys()
# Out:
# <Response [200]>
# dict_keys(['list_total_count', 'RESULT', 'row'])

# %%
res_apply_ys = apply_yongsan['YsModelRestaurantApply']['row']
data_2 = pd.DataFrame(res_apply_ys)
print(data_2)
# Out:
#     CGG_CODE ASGN_YY ASGN_SNO  APPL_YMD  ASGN_YMD ASGN_CANCEL_YMD IPSB_YMD  \
# 0    3020000    2022     0006  20220819  20220921
# 1    3020000    2022     0009  20220819  20220921        20230522
# 2    3020000    2022     0013  20220819  20220921
# 3    3020000    2022     0012  20220819  20220921
# 4    3020000    2022     0005  20220819  20220921
# ..       ...     ...      ...       ...       ...             ...      ...
# 193  3020000    2003     0019  20060630  20030731
# 194  3020000    2008     0014  20060630  20080829        20080829
# 195  3020000    2015     0056  20060630  20151211        20201104
# 196  3020000    2005     101   20060630  20050725        20131231
# 197  3020000    2001     86    20060630  20010630        20050725
#
#            UPSO_NM                                     SITE_ADDR_RD  \
# 0               미성            서울특별시 용산구 한강대로84길 12, 미성회관 1,2층 (남영동)
# 1             나주곰탕                   서울특별시 용산구 한강대로 270, 지상1층 (남영동)
# ...

# %%
data_2.to_csv("모범음식점신청현황(용산구).csv", index=False)

# %%
import requests
import pandas as pd

data =None
for j in range(1, 3):
    
    url = f"http://openapi.seoul.go.kr:8088/4b506461526c736f3238486c426578/json/VwsmTrdhlFlpopQq/{1+((j-1)*1000)}/{j*1000}"
    # print(url)
    req = requests.get(url)
    # print(req)
    content = req.json()
    con = content['VwsmTrdhlFlpopQq']['row']
    result = pd.DataFrame(con)
    data = pd.concat([data, result])

data.head()
    
# df 
# df.keys()
# df['VwsmTrdhlFlpopQq'].keys()
# Out:
#   STDR_YY_CD STDR_QU_CD TRDAR_SE_CD TRDAR_SE_CD_NM TRDAR_CD TRDAR_CD_NM  \
# 0       2022          1           A           골목상권  2110328     상월곡역 3번
# 1       2022          2           A           골목상권  2110002     독립문역 1번
# 2       2022          4           A           골목상권  2110354  삼각산119안전센터
# 3       2022          1           A           골목상권  2110567     광흥창역 6번
# 4       2022          3           A           골목상권  2110783   영등포시장역 1번
#
#    TOT_FLPOP_CO  ML_FLPOP_CO  FML_FLPOP_CO  AGRDE_10_FLPOP_CO  ...  \
# 0     3743520.0    1720322.0     2023196.0           493501.0  ...
# 1     1666942.0     774712.0      892229.0           329952.0  ...
# 2     3200084.0    1465631.0     1734454.0           569051.0  ...
# 3     2120148.0     973988.0     1146160.0           390284.0  ...
# 4     3642386.0    1751616.0     1890771.0           475139.0  ...
#
#    FAG_60_ABOVE_SATTM_3_FLPOP_CO  FAG_60_ABOVE_SATTM_4_FLPOP_CO  \
# ...

# %%
df1 = df['VwsmTrdhlFlpopQq']['row']
data_3 = pd.DataFrame(df1)
print(data_3)
# Out:
#     STDR_YY_CD STDR_QU_CD TRDAR_SE_CD TRDAR_SE_CD_NM TRDAR_CD TRDAR_CD_NM  \
# 0         2022          1           A           골목상권  2110328     상월곡역 3번
# 1         2022          2           A           골목상권  2110002     독립문역 1번
# 2         2022          4           A           골목상권  2110354  삼각산119안전센터
# 3         2022          1           A           골목상권  2110567     광흥창역 6번
# 4         2022          3           A           골목상권  2110783   영등포시장역 1번
# ..         ...        ...         ...            ...      ...         ...
# 995       2022          1           A           골목상권  2111063  강동구립 천호도서관
# 996       2022          4           A           골목상권  2110189     제기동역 1번
# 997       2022          1           A           골목상권  2111064     둔촌동역 4번
# 998       2022          4           A           골목상권  2110190      고대앞사거리
# 999       2022          1           A           골목상권  2111065      천일초등학교
#
#      TOT_FLPOP_CO  ML_FLPOP_CO  FML_FLPOP_CO  AGRDE_10_FLPOP_CO  ...  \
# ...

# %%
data_3.to_csv("서울시 상권분석서비스(상권배후지_생활인구).csv", index=False)

# %%
import requests
import pandas as pd

data =None
for j in range(1, 10):
    
    url = f"http://openapi.seoul.go.kr:8088/4b506461526c736f3238486c426578/json/ppsOrgnCt/{1+((j-1)*1000)}/{j*1000}"
    # print(url)
    # req = requests.get(url)
    # print(req)
    content = req.json()
    
    con = content['ppsOrgnCt']['row']
    result = pd.DataFrame(con)
    data = pd.concat([data, result])

data
    
# df 
# df.keys()
# df['VwsmTrdhlFlpopQq'].keys()
# Out:
#     STDR_DE_ID TMZON_PD_SE ADSTRD_CODE_SE LVPOP_SN MLNG_RESDNC_CODE_SE  \
# 0     20230802          00       11140570       49               41171
# 1     20230802          00       11140570       50               41500
# 2     20230802          00       11140570       51               41670
# 3     20230802          00       11140570       52               41173
# 4     20230802          00       11140570       53               28110
# ..         ...         ...            ...      ...                 ...
# 995   20230802          00       11170590        9               41450
# 996   20230802          00       11170590       10               27000
# 997   20230802          00       11170590       11               41133
# 998   20230802          00       11170590       12               41220
# 999   20230802          00       11170590       13               29000
#
#            TOT_LVPOP_CO MALE_F10T14_LVPOP_CO MALE_F15T19_LVPOP_CO  \
# ...

# %%
data.to_csv("서울생활인구대도시권내외국민.csv", index=False)

# %%
import requests
import pandas as pd

data =None
for j in range(1, 3):
    
    url = f"http://openapi.seoul.go.kr:8088/4b506461526c736f3238486c426578/json/VwsmTrdhlFlpopQq/{1+((j-1)*1000)}/{j*1000}"
    # print(url)
    req = requests.get(url)
    # print(req)
    content = req.json()
    con = content['VwsmTrdhlFlpopQq']['row']
    result = pd.DataFrame(con)
    data = pd.concat([data, result])

data.head()
    
# df 
# df.keys()
# df['VwsmTrdhlFlpopQq'].keys()
